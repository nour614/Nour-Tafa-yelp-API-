# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in /Users/nourtafa/anaconda3/envs/dojo-env/lib/python3.9/site-packages (2.5.0)
# Requirement already satisfied: requests in /Users/nourtafa/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/nourtafa/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nourtafa/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/nourtafa/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nourtafa/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: tqdm in /Users/nourtafa/anaconda3/envs/dojo-env/lib/python3.9/site-packages (4.64.1)

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
# os - for saving and loading files
# json - to work with json files
# math - to round up results
# time - to add a short pause to not overwhelm the server
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open('/Users/nourtafa/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s = 5.0)

# %% [markdown]
# Define Search Terms and File Paths

# %%
# set our API call parameters 
LOCATION = 'Philadelphia, PA'
TERM = 'Philly cheesesteak'

# %%
LOCATION.split(',')[0]
# Out:
# 'Philadelphia'

# %%
## Specify fodler for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{LOCATION.split(',')[0]}-{TERM}.json"

# %%
JSON_FILE
# Out:
# 'Data/Philadelphia-Philly cheesesteak.json'

# %% [markdown]
# Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Philadelphia-Philly cheesesteak.json already exists.

# %%
## Load previous results and use len of results for offset
with open(JSON_FILE,'r') as f:
    previous_results = json.load(f)
    
## set offset based on previous results
n_results = len(previous_results)
print(f'- {n_results} previous results found.')
# Out:
# - 0 previous results found.

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(location=LOCATION,
                                term=TERM,
                               offset=n_results)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 1100

# %%
results['region']
# Out:
# {'center': {'longitude': -75.11764526367188, 'latitude': 40.00218959599397}}

# %%
results['businesses']
# Out:
# [{'id': 'RQAF6a0akMiot5lZZnMNNw',
#   'alias': 'dalessandro-s-steaks-and-hoagies-philadelphia',
#   'name': 'Dalessandro’s Steaks & Hoagies',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yGVA9fRK4ijYuAdhjJK_fA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dalessandro-s-steaks-and-hoagies-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 3159,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.029494, 'longitude': -75.2059714},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '600 Wendover St',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19128',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['600 Wendover St', 'Philadelphia, PA 19128']},
#   'phone': '+12154825407',
#   'display_phone': '(215) 482-5407',
#   'distance': 8111.519762456322},
#  {'id': '-mIlmp5l4hKlp1tvHRdvTg',
#   'alias': 'sonnys-famous-steaks-philadelphia',
#   'name': "Sonny's Famous Steaks",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c333HAywM9J_sFCTTb-JPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sonnys-famous-steaks-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 1887,
#   'categories': [{'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.94982923010674,
#    'longitude': -75.1447920753477},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '228 Market St',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19106',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['228 Market St', 'Philadelphia, PA 19106']},
#   'phone': '+12156295760',
#   'display_phone': '(215) 629-5760',
#   'distance': 6264.888631248105},
#  {'id': 'LM54ufrINJWoTN5imV8Etw',
#   'alias': 'johns-roast-pork-philadelphia',
#   'name': "John's Roast Pork",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qPyjRa1Bu9W6_iC45bth5A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/johns-roast-pork-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 1746,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.9210273851256, 'longitude': -75.14502844377},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '14 E Snyder Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19148',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['14 E Snyder Ave', 'Philadelphia, PA 19148']},
#   'phone': '+12154631951',
#   'display_phone': '(215) 463-1951',
#   'distance': 9321.694746230763},
#  {'id': 'PP3BBaVxZLcJU54uP_wL6Q',
#   'alias': 'pats-king-of-steaks-philadelphia-5',
#   'name': "pat's king of steaks",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/f-Kogk9BssNsJO_kQIt28A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pats-king-of-steaks-philadelphia-5?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 4533,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.9332010582612,
#    'longitude': -75.1592658139918},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1237 E Passyunk Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19147',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1237 E Passyunk Ave', 'Philadelphia, PA 19147']},
#   'phone': '+12154681546',
#   'display_phone': '(215) 468-1546',
#   'distance': 8451.476279759412},
#  {'id': 'IkY2ticzHEn4QFn8hQLSWg',
#   'alias': 'genos-steaks-philadelphia',
#   'name': "Geno's Steaks",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/meMxwQNMA9GckN7aHOoyxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/genos-steaks-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 3621,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.9338367849925, 'longitude': -75.158813752375},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1219 S 9th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19147',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1219 S 9th St', 'Philadelphia, PA 19147']},
#   'phone': '+12153890659',
#   'display_phone': '(215) 389-0659',
#   'distance': 8371.140101552244},
#  {'id': 'cFSyJluKa2SHtgMMvlx6SQ',
#   'alias': 'angelos-pizzeria-philadelphia',
#   'name': "Angelo's Pizzeria",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iz4rk2w-_a63uS8IKE3_Fw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/angelos-pizzeria-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 588,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.940651781214825,
#    'longitude': -75.15761362207279},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '736 S 9th St',
#    'address2': '',
#    'address3': None,
#    'city': 'Philadelphia',
#    'zip_code': '19147',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['736 S 9th St', 'Philadelphia, PA 19147']},
#   'phone': '+12159220000',
#   'display_phone': '(215) 922-0000',
#   'distance': 7643.476658858134},
#  {'id': 'jxEMFqwDJXjCxmcm5t5jVQ',
#   'alias': 'cleavers-philadelphia',
#   'name': 'Cleavers',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9dfyW_xnDKvjwsFchGuW8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cleavers-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 1538,
#   'categories': [{'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.9513931274414,
#    'longitude': -75.1706237792969},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '108 S 18th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19103',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['108 S 18th St', 'Philadelphia, PA 19103']},
#   'phone': '+12155153828',
#   'display_phone': '(215) 515-3828',
#   'distance': 7227.9167503382205},
#  {'id': 'q-zV08jt6U-q05SMEuQJAQ',
#   'alias': 'tony-and-nicks-steaks-philadelphia',
#   'name': "Tony & Nick's Steaks",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NW552nlzKhdSXOrXmJDqZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tony-and-nicks-steaks-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 2014,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.9141065085686, 'longitude': -75.148727230422},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '39 E Oregon Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19148',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['39 E Oregon Ave', 'Philadelphia, PA 19148']},
#   'phone': '+12155515725',
#   'display_phone': '(215) 551-5725',
#   'distance': 10146.334732517982},
#  {'id': '7pAgxBMUjrVPH7xh3fn-gw',
#   'alias': 'oh-brother-philly-philadelphia',
#   'name': 'Oh Brother Philly',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YbjY1z_XuFVSxw1Itfh15g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/oh-brother-philly-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 744,
#   'categories': [{'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.94971, 'longitude': -75.14411},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '206 Market St',
#    'address2': '',
#    'address3': None,
#    'city': 'Philadelphia',
#    'zip_code': '19106',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['206 Market St', 'Philadelphia, PA 19106']},
#   'phone': '+12155153255',
#   'display_phone': '(215) 515-3255',
#   'distance': 6258.740847929766},
#  {'id': 'LFyuwzv0CHgR44y0XSJbPA',
#   'alias': 'leos-steak-shop-folcroft',
#   'name': "Leo's Steak Shop",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9R5m0_63oyOvZKEE6etNLg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/leos-steak-shop-folcroft?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 617,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.90521, 'longitude': -75.27942},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1403 Chester Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Folcroft',
#    'zip_code': '19032',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1403 Chester Pike', 'Folcroft, PA 19032']},
#   'phone': '+16104619901',
#   'display_phone': '(610) 461-9901',
#   'distance': 17507.961497700828},
#  {'id': 'IWHdx0NhDKADkGOgXgOFKQ',
#   'alias': 'tommy-dinics-philadelphia',
#   'name': "Tommy DiNic's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xPGRDCXmPXLstxQAPFb8yg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tommy-dinics-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 2336,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.953478370008, 'longitude': -75.1593960603483},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1136 Arch St',
#    'address2': '',
#    'address3': 'Reading Terminal Market',
#    'city': 'Philadelphia',
#    'zip_code': '19147',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1136 Arch St',
#     'Reading Terminal Market',
#     'Philadelphia, PA 19147']},
#   'phone': '+12159236175',
#   'display_phone': '(215) 923-6175',
#   'distance': 6480.241483024119},
#  {'id': 'nzEeYl3o-S9F0MikdDkgnw',
#   'alias': 'philly-steak-philadelphia-3',
#   'name': 'Philly Steak',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uIaGiOfl9Zp_7q6Anq70WA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/philly-steak-philadelphia-3?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 14,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 39.95473827644856,
#    'longitude': -75.16895319999999},
#   'transactions': [],
#   'location': {'address1': '1701 John F Kennedy Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Philadelphia',
#    'zip_code': '19103',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1701 John F Kennedy Blvd', 'Philadelphia, PA 19103']},
#   'phone': '+12675198200',
#   'display_phone': '(267) 519-8200',
#   'distance': 6852.179587437848},
#  {'id': 'Jn4tRtjIuz6MBCykQySpeg',
#   'alias': 'woodrows-sandwich-shop-philadelphia',
#   'name': "Woodrow's Sandwich Shop",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p1XMYC9HqAe5ws14uKYpZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/woodrows-sandwich-shop-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 417,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.9419326782227,
#    'longitude': -75.1531982421875},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '630 South St',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19147',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['630 South St', 'Philadelphia, PA 19147']},
#   'phone': '+12154703559',
#   'display_phone': '(215) 470-3559',
#   'distance': 7349.872241131098},
#  {'id': '9ggTidLF9LPNdyWdCGtrYg',
#   'alias': 'gooey-looies-philadelphia',
#   'name': "Gooey Looie's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rE9AuN885fItIyGl0ZK8jw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gooey-looies-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 293,
#   'categories': [{'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.92534, 'longitude': -75.15075},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '231 McClellan St',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19148',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['231 McClellan St', 'Philadelphia, PA 19148']},
#   'phone': '+12153347668',
#   'display_phone': '(215) 334-7668',
#   'distance': 8997.835330497946},
#  {'id': 'Zqd_DHAtrdzRJ8u3zwrvEA',
#   'alias': 'hershels-east-side-deli-philadelphia',
#   'name': "Hershel's East Side Deli",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/71H66DB4CKCABZo0mQHJWg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hershels-east-side-deli-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 815,
#   'categories': [{'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.953284, 'longitude': -75.159403},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '51 N 12th St',
#    'address2': '',
#    'address3': 'Reading Terminal Market',
#    'city': 'Philadelphia',
#    'zip_code': '19107',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['51 N 12th St',
#     'Reading Terminal Market',
#     'Philadelphia, PA 19107']},
#   'phone': '+12159226220',
#   'display_phone': '(215) 922-6220',
#   'distance': 6498.643738395057},
#  {'id': '4wq9bzoCe3Mh0cPbYH1eDg',
#   'alias': 'maxs-steaks-philadelphia',
#   'name': "Max's Steaks",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OhGLUPggAELOuXNUpHIJDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maxs-steaks-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 792,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.009045, 'longitude': -75.150471},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3653 Germantown Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19140',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['3653 Germantown Ave', 'Philadelphia, PA 19140']},
#   'phone': '+12152299048',
#   'display_phone': '(215) 229-9048',
#   'distance': 2897.9261664449773},
#  {'id': 'YPLfRswyryjjW3VJa-SdaA',
#   'alias': 'ishkabibbles-philadelphia',
#   'name': "Ishkabibble's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PkX4o32z8TZn4HdwzTBAKA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ishkabibbles-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 795,
#   'categories': [{'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.9416902, 'longitude': -75.14875769999999},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '337 S St',
#    'address2': None,
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19147',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['337 S St', 'Philadelphia, PA 19147']},
#   'phone': '+12159234337',
#   'display_phone': '(215) 923-4337',
#   'distance': 7230.808954424802},
#  {'id': 'GXqzvoBm9iEZ_R6Ubeqzrw',
#   'alias': 'steves-prince-of-steaks-langhorne',
#   'name': "Steve's Prince of Steaks",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sMiQf5wcPSN3o_YQMfYKWQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/steves-prince-of-steaks-langhorne?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 217,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.172279, 'longitude': -74.890116},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1617 E Lincoln Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Langhorne',
#    'zip_code': '19047',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1617 E Lincoln Hwy', 'Langhorne, PA 19047']},
#   'phone': '+12159434640',
#   'display_phone': '(215) 943-4640',
#   'distance': 27062.243873158972},
#  {'id': 'wHkYLlZyPXllrQRlvidUlg',
#   'alias': 'campos-philly-cheesesteaks-philadelphia',
#   'name': "Campo's Philly Cheesesteaks",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nQNH-WP3Ad19-To2ab9VNw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/campos-philly-cheesesteaks-philadelphia?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 794,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.9497014, 'longitude': -75.1442745},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '214 Market St',
#    'address2': '',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19106',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['214 Market St', 'Philadelphia, PA 19106']},
#   'phone': '+12159231000',
#   'display_phone': '(215) 923-1000',
#   'distance': 6261.985746139045},
#  {'id': 'BonnUxyWs1ymbFASgmJ5Qg',
#   'alias': 'philly-cheesesteaks-berwyn',
#   'name': 'Philly Cheesesteaks',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jvZYthi9XkFdfoci2OiGFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/philly-cheesesteaks-berwyn?adjust_creative=PPh82t5T8b6EVvQrQMiv2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PPh82t5T8b6EVvQrQMiv2w',
#   'review_count': 53,
#   'categories': [{'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.047362, 'longitude': -75.4425979033113},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '676 Lancaster Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Berwyn',
#    'zip_code': '19312',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['676 Lancaster Ave', 'Berwyn, PA 19312']},
#   'phone': '+16107229464',
#   'display_phone': '(610) 722-9464',
#   'distance': 28121.675234173657}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                          alias  \
# 0   RQAF6a0akMiot5lZZnMNNw  dalessandro-s-steaks-and-hoagies-philadelphia
# 1   -mIlmp5l4hKlp1tvHRdvTg              sonnys-famous-steaks-philadelphia
# 2   LM54ufrINJWoTN5imV8Etw                  johns-roast-pork-philadelphia
# 3   PP3BBaVxZLcJU54uP_wL6Q             pats-king-of-steaks-philadelphia-5
# 4   IkY2ticzHEn4QFn8hQLSWg                      genos-steaks-philadelphia
# 5   cFSyJluKa2SHtgMMvlx6SQ                  angelos-pizzeria-philadelphia
# 6   jxEMFqwDJXjCxmcm5t5jVQ                          cleavers-philadelphia
# 7   q-zV08jt6U-q05SMEuQJAQ             tony-and-nicks-steaks-philadelphia
# 8   7pAgxBMUjrVPH7xh3fn-gw                 oh-brother-philly-philadelphia
# 9   LFyuwzv0CHgR44y0XSJbPA                       leos-steak-shop-folcroft
# 10  IWHdx0NhDKADkGOgXgOFKQ                      tommy-dinics-philadelphia
# 11  nzEeYl3o-S9F0MikdDkgnw                    philly-steak-philadelphia-3
# 12  Jn4tRtjIuz6MBCykQySpeg            woodrows-sandwich-shop-philadelphia
# 13  9ggTidLF9LPNdyWdCGtrYg                      gooey-looies-philadelphia
# 14  Zqd_DHAtrdzRJ8u3zwrvEA           hershels-east-side-deli-philadelphia
# 15  4wq9bzoCe3Mh0cPbYH1eDg                       maxs-steaks-philadelphia
# 16  YPLfRswyryjjW3VJa-SdaA                      ishkabibbles-philadelphia
# 17  GXqzvoBm9iEZ_R6Ubeqzrw              steves-prince-of-steaks-langhorne
# 18  wHkYLlZyPXllrQRlvidUlg        campos-philly-cheesesteaks-philadelphia
# 19  BonnUxyWs1ymbFASgmJ5Qg                     philly-cheesesteaks-berwyn
#
#                               name  \
# 0   Dalessandro’s Steaks & Hoagies
# 1            Sonny's Famous Steaks
# 2                John's Roast Pork
# 3             pat's king of steaks
# 4                    Geno's Steaks
# 5                Angelo's Pizzeria
# 6                         Cleavers
# 7             Tony & Nick's Steaks
# 8                Oh Brother Philly
# 9                 Leo's Steak Shop
# 10                   Tommy DiNic's
# 11                    Philly Steak
# 12         Woodrow's Sandwich Shop
# 13                   Gooey Looie's
# 14        Hershel's East Side Deli
# 15                    Max's Steaks
# 16                   Ishkabibble's
# 17        Steve's Prince of Steaks
# 18     Campo's Philly Cheesesteaks
# 19             Philly Cheesesteaks
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/yGVA9f...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/c333HA...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/qPyjRa...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/f-Kogk...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/meMxwQ...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/iz4rk2...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/9dfyW_...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/NW552n...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/YbjY1z...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/9R5m0_...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/xPGRDC...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/uIaGiO...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/p1XMYC...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/rE9AuN...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/71H66D...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/OhGLUP...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/PkX4o3...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/sMiQf5...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/nQNH-W...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/jvZYth...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/dalessandro-s-steaks-...          3159
# 1   https://www.yelp.com/biz/sonnys-famous-steaks-...          1887
# 2   https://www.yelp.com/biz/johns-roast-pork-phil...          1746
# 3   https://www.yelp.com/biz/pats-king-of-steaks-p...          4533
# 4   https://www.yelp.com/biz/genos-steaks-philadel...          3621
# 5   https://www.yelp.com/biz/angelos-pizzeria-phil...           588
# 6   https://www.yelp.com/biz/cleavers-philadelphia...          1538
# 7   https://www.yelp.com/biz/tony-and-nicks-steaks...          2014
# 8   https://www.yelp.com/biz/oh-brother-philly-phi...           744
# 9   https://www.yelp.com/biz/leos-steak-shop-folcr...           617
# 10  https://www.yelp.com/biz/tommy-dinics-philadel...          2336
# 11  https://www.yelp.com/biz/philly-steak-philadel...            14
# 12  https://www.yelp.com/biz/woodrows-sandwich-sho...           417
# 13  https://www.yelp.com/biz/gooey-looies-philadel...           293
# 14  https://www.yelp.com/biz/hershels-east-side-de...           815
# 15  https://www.yelp.com/biz/maxs-steaks-philadelp...           792
# 16  https://www.yelp.com/biz/ishkabibbles-philadel...           795
# 17  https://www.yelp.com/biz/steves-prince-of-stea...           217
# 18  https://www.yelp.com/biz/campos-philly-cheeses...           794
# 19  https://www.yelp.com/biz/philly-cheesesteaks-b...            53
#
#                                            categories  rating  \
# 0   [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.0
# 1   [{'alias': 'cheesesteaks', 'title': 'Cheeseste...     4.0
# 2   [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.5
# 3   [{'alias': 'sandwiches', 'title': 'Sandwiches'...     3.0
# 4   [{'alias': 'sandwiches', 'title': 'Sandwiches'...     2.5
# 5   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 6   [{'alias': 'cheesesteaks', 'title': 'Cheeseste...     4.0
# 7   [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.0
# 8   [{'alias': 'cheesesteaks', 'title': 'Cheeseste...     4.5
# 9   [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.5
# 10  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 11  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     5.0
# 12  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.5
# 13  [{'alias': 'delis', 'title': 'Delis'}, {'alias...     4.5
# 14  [{'alias': 'delis', 'title': 'Delis'}, {'alias...     4.5
# 15  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.0
# 16  [{'alias': 'cheesesteaks', 'title': 'Cheeseste...     4.0
# 17   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     4.0
# 18  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     3.5
# 19  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     4.5
#
#                                           coordinates        transactions  \
# 0   {'latitude': 40.029494, 'longitude': -75.2059714}          [delivery]
# 1   {'latitude': 39.94982923010674, 'longitude': -...  [pickup, delivery]
# 2   {'latitude': 39.9210273851256, 'longitude': -7...  [pickup, delivery]
# 3   {'latitude': 39.9332010582612, 'longitude': -7...  [pickup, delivery]
# 4   {'latitude': 39.9338367849925, 'longitude': -7...  [pickup, delivery]
# 5   {'latitude': 39.940651781214825, 'longitude': ...          [delivery]
# 6   {'latitude': 39.9513931274414, 'longitude': -7...  [pickup, delivery]
# 7   {'latitude': 39.9141065085686, 'longitude': -7...  [pickup, delivery]
# 8      {'latitude': 39.94971, 'longitude': -75.14411}  [pickup, delivery]
# 9      {'latitude': 39.90521, 'longitude': -75.27942}          [delivery]
# 10  {'latitude': 39.953478370008, 'longitude': -75...  [pickup, delivery]
# 11  {'latitude': 39.95473827644856, 'longitude': -...                  []
# 12  {'latitude': 39.9419326782227, 'longitude': -7...  [pickup, delivery]
# 13     {'latitude': 39.92534, 'longitude': -75.15075}                  []
# 14   {'latitude': 39.953284, 'longitude': -75.159403}  [pickup, delivery]
# 15   {'latitude': 40.009045, 'longitude': -75.150471}                  []
# 16  {'latitude': 39.9416902, 'longitude': -75.1487...          [delivery]
# 17   {'latitude': 40.172279, 'longitude': -74.890116}          [delivery]
# 18  {'latitude': 39.9497014, 'longitude': -75.1442...  [pickup, delivery]
# 19  {'latitude': 40.047362, 'longitude': -75.44259...  [pickup, delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '600 Wendover St', 'address2': ''...  +12154825407
# 1     $$  {'address1': '228 Market St', 'address2': '', ...  +12156295760
# 2     $$  {'address1': '14 E Snyder Ave', 'address2': ''...  +12154631951
# 3     $$  {'address1': '1237 E Passyunk Ave', 'address2'...  +12154681546
# 4     $$  {'address1': '1219 S 9th St', 'address2': '', ...  +12153890659
# 5     $$  {'address1': '736 S 9th St', 'address2': '', '...  +12159220000
# 6     $$  {'address1': '108 S 18th St', 'address2': '', ...  +12155153828
# 7     $$  {'address1': '39 E Oregon Ave', 'address2': ''...  +12155515725
# 8     $$  {'address1': '206 Market St', 'address2': '', ...  +12155153255
# 9     $$  {'address1': '1403 Chester Pike', 'address2': ...  +16104619901
# 10    $$  {'address1': '1136 Arch St', 'address2': '', '...  +12159236175
# 11   NaN  {'address1': '1701 John F Kennedy Blvd', 'addr...  +12675198200
# 12    $$  {'address1': '630 South St', 'address2': '', '...  +12154703559
# 13     $  {'address1': '231 McClellan St', 'address2': '...  +12153347668
# 14    $$  {'address1': '51 N 12th St', 'address2': '', '...  +12159226220
# 15    $$  {'address1': '3653 Germantown Ave', 'address2'...  +12152299048
# 16    $$  {'address1': '337 S St', 'address2': None, 'ad...  +12159234337
# 17    $$  {'address1': '1617 E Lincoln Hwy', 'address2':...  +12159434640
# 18    $$  {'address1': '214 Market St', 'address2': '', ...  +12159231000
# 19   NaN  {'address1': '676 Lancaster Ave', 'address2': ...  +16107229464
#
#      display_phone      distance
# 0   (215) 482-5407   8111.519762
# 1   (215) 629-5760   6264.888631
# 2   (215) 463-1951   9321.694746
# 3   (215) 468-1546   8451.476280
# 4   (215) 389-0659   8371.140102
# 5   (215) 922-0000   7643.476659
# 6   (215) 515-3828   7227.916750
# 7   (215) 551-5725  10146.334733
# 8   (215) 515-3255   6258.740848
# 9   (610) 461-9901  17507.961498
# 10  (215) 923-6175   6480.241483
# 11  (267) 519-8200   6852.179587
# 12  (215) 470-3559   7349.872241
# 13  (215) 334-7668   8997.835330
# 14  (215) 922-6220   6498.643738
# 15  (215) 229-9048   2897.926166
# 16  (215) 923-4337   7230.808954
# 17  (215) 943-4640  27062.243873
# 18  (215) 923-1000   6261.985746
# 19  (610) 722-9464  28121.675234

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 55

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/55 [00:00<?, ?it/s]
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined
#  [!] ERROR name 'location' is not defined

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 0 entries
# Empty DataFrame

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Philadelphia-Philly cheesesteak.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)

# %% [markdown]
# Bonus: compare filesize with os module's os.path.getsize

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 2 Bytes
# CSV.GZ FILE: 63 Bytes
# the csv.gz is 0.031746031746031744 times smaller!
